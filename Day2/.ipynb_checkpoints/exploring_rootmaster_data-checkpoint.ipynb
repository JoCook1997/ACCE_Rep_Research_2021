# %%
#code to produce plots using the root-master data 

#date created 05/05/2021
#last edited 05/05/2021
#Jo Cook

# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
#specify directory where data is stored, so any following paths are relative to this directory
os.chdir(r'C:/Users/JoCook/Documents/PhD/ACCE_Reproducible_Research_Course/Day1/data')

#read in data
data=pd.read_csv(r'processed_data.csv')

# %%
#get column names
#list(data.columns)

# %%
#summary statistics
summary=data.describe()
summary
# Out:
#        stemDiameter  measurementHeight        height       pointID  \
# count  13615.000000       13063.000000  13250.000000  14961.000000
# mean      20.209614         127.846207     11.268672     41.933293
# std       14.053612          20.700539      7.292483     12.982901
# min        1.000000           1.000000      0.300000     21.000000
# 25%       11.600000         130.000000      5.300000     33.000000
# 50%       16.500000         130.000000     10.600000     41.000000
# 75%       26.300000         130.000000     16.200000     51.000000
# max      373.300000         200.000000    119.800000    258.000000
#
#        stemDistance   stemAzimuth  decimalLatitude  decimalLongitude  \
# count  14961.000000  14961.000000     14961.000000      14961.000000
# mean      10.458124    177.401491        36.012452        -77.083286
# std        6.226796    103.307009         8.614549          7.795612
# min        0.000000      0.100000        17.955704        -99.111067
# 25%        5.800000     90.200000        32.539653        -83.503885
# 50%        9.600000    174.000000        39.057517        -72.253256
# 75%       14.000000    265.400000        44.060736        -71.285609
# max       37.100000    360.000000        47.165821        -66.824633
#
#              easting      northing     elevation  elevationUncertainty  \
# count   14961.000000  1.496100e+04  14961.000000          14961.000000
# mean   475494.698161  3.988152e+06    250.505334              0.227364
# std    190825.710750  9.555800e+05    190.003773              0.099704
# min    270857.350000  1.986600e+06     17.500000              0.100000
# 25%    316774.780000  3.600537e+06    116.700000              0.100000
# 50%    424300.050000  4.327234e+06    245.400000              0.200000
# 75%    726055.250000  4.881160e+06    302.900000              0.300000
# max    763405.120000  5.223597e+06    673.000000              0.600000
#
#             stemLat       stemLon
# count  14961.000000  14961.000000
# mean      36.012452    -77.083277
# std        8.614549      7.795619
# min       17.955755    -99.111129
# 25%       32.539794    -83.503910
# 50%       39.057455    -72.253347
# 75%       44.060729    -71.285668
# max       47.165907    -66.824542

# %%
#density plot of stemDiameter
sns.distplot(data['stemDiameter'])
# Out:
# C:\Users\JoCook\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stemDiameter', ylabel='Density'>

# %%
#density plot of stemDiameter - logscale
sns.kdeplot(data['stemDiameter'],log_scale=True, color='green',shade=True)
# Out:
# <AxesSubplot:xlabel='stemDiameter', ylabel='Density'>

# %%
#density plot of height
sns.kdeplot(data['height'], color='red',shade=True)
# Out:
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
#density plot of height
sns.kdeplot(data['height'],log_scale=True, color='red',shade=True)
# Out:
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
#note - seaborns doesn't show n/a values like R did

#barplot of growth form
fig, ax1 = plt.subplots(figsize=(10,5))
sns.countplot(data['growthForm'],ax=ax1,order=data['growthForm'].value_counts(ascending=True).index)
# Out:
# C:\Users\JoCook\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='growthForm', ylabel='count'>

# %%
#to drop the liana rows for analysis
analysis_data=data.drop(data.loc[data['growthForm']=='liana'].index)

#new countplot w/o liana and reformatted
fig, ax2 = plt.subplots(figsize=(10,5))
ax2.set_facecolor('gainsboro')
sns.countplot(y=analysis_data['growthForm'],ax=ax2,order=analysis_data['growthForm'].value_counts(ascending=False).index,
             palette='PuRd',edgecolor='black')

#set up gridlines
ax2.set_axisbelow(True)
ax2.grid(b=True, which='major', linestyle='-', linewidth='0.6', color='white')

# %%
#multiple distributions on one plot, log(stemDiameter) for each type of growthForm
sns.displot(data=analysis_data, x='stemDiameter', hue='growthForm', kind='kde',log_scale=True,palette='viridis')
#note-haven't changed the title of x axis to say log(stemDiameter)
#note-doesn't look the same as in the R notes, y density values are not the same

# %%
#violinplot for stemdiameter
fig, ax3 = plt.subplots(figsize=(10,5))
ax3.set_facecolor('gainsboro')
sns.violinplot(x = np.log(analysis_data['stemDiameter']), y = analysis_data['growthForm'],ax=ax3,
             palette='YlGnBu',edgecolor='black')

#set up gridlines
ax3.set_axisbelow(True)
ax3.grid(b=True, which='major', linestyle='-', linewidth='0.6', color='white')

#axis titles
ax3.set_xlabel('log(stemDiameter)')
ax3.set_ylabel('growthForm')
# Out:
# Text(0, 0.5, 'growthForm')

# %%
#violinplot for stemheight
fig, ax4 = plt.subplots(figsize=(10,5))
ax4.set_facecolor('gainsboro')
sns.violinplot(x = np.log(analysis_data['height']), y = analysis_data['growthForm'],ax=ax4,
             palette='YlGnBu',edgecolor='black')

#set up gridlines
ax4.set_axisbelow(True)
ax4.grid(b=True, which='major', linestyle='-', linewidth='0.6', color='white')

#axis titles
ax4.set_xlabel('log(height)')
ax4.set_ylabel('growthForm')
# Out:
# Text(0, 0.5, 'growthForm')

# %%
#put both those violin plot on one plot

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 14

#set up plot
fig = plt.subplots(figsize=(15,5))
ax5=plt.subplot2grid((1,2),(0,0), rowspan=1, colspan=1) #subplot2grid(shape, location, rowspan, colspan)
ax6=plt.subplot2grid((1,2),(0,1), rowspan=1, colspan=1)

#set the spacing between the subplots
plt.tight_layout(w_pad=0, h_pad=0)
#-----------------------------------------------------------
#stemDiameter code

ax5.set_facecolor('gainsboro')
sns.violinplot(x = np.log(analysis_data['stemDiameter']), y = analysis_data['growthForm'],ax=ax5,
             palette='YlGnBu',edgecolor='black')

#set up gridlines
ax5.set_axisbelow(True)
ax5.grid(b=True, which='major', linestyle='-', linewidth='0.6', color='white')

#axis titles
ax5.set_xlabel('')
ax5.set_title('Stem Diameter')
ax5.set_ylabel('Growth Form')

#-----------------------------------------------------------
#height code

ax6.set_facecolor('gainsboro')
sns.violinplot(x = np.log(analysis_data['height']), y = analysis_data['growthForm'],ax=ax6,
             palette='YlGnBu',edgecolor='black')

#set up gridlines
ax6.set_axisbelow(True)
ax6.grid(b=True, which='major', linestyle='-', linewidth='0.6', color='white')

#axis titles
ax6.set_xlabel('')
ax6.set_ylabel('')
ax6.set_title('Height')
ax6.set_yticks([])
plt.text(0.475, 0, 'log(Value)', fontsize=14, transform=plt.gcf().transFigure)
# Out:
# Text(0.475, 0, 'log(Value)')

# %%
#scatter plot of log(stemDiameter) vs log(height)

#set up plot
fig, ax7 = plt.subplots(figsize=(10,5))
ax7.set_facecolor('gainsboro')

#make the scatterplot
sns.regplot(np.log(analysis_data['height']), np.log(analysis_data['stemDiameter']), ax=ax7,fit_reg=True,
           color='deeppink',line_kws={'color':'black'})

#alter labels
ax7.set_xlabel('log(height)')
ax7.set_ylabel('log(stemDiameter)')

#set up gridlines
ax7.set_axisbelow(True)
ax7.grid(b=True, which='major', linestyle='-', linewidth='0.6', color='white')
# Out:
# C:\Users\JoCook\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#scatter plot of log(stemDiameter) vs log(height)

#get the data for the plot, lmplot doesn't allow dataframe columns to be passed as arguments
#this means we have to get the log of the variables before passing it
get_data=[analysis_data['height'],analysis_data['stemDiameter'],analysis_data['growthForm']]
headers = ['height', 'stemDiameter','growthForm']
data_to_plot = pd.concat(get_data, axis=1, keys=headers)
data_to_plot['log(height)']=np.log(data_to_plot['height'])
data_to_plot['log(stemDiameter)']=np.log(data_to_plot['stemDiameter'])

#make the scatterplot with regressions
ax8=sns.lmplot(x='log(height)', y='log(stemDiameter)', data=data_to_plot, hue='growthForm',palette='viridis')
